# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,Y=make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %% [markdown]
# ## Implementation

# %%
k=5
colors=["red","blue","green","orange","yellow"]
clusters={}

for i in range(k):
    centre=10*(2*np.random.random((X.shape[1]),)-1)
    points=[]
    cluster={
        'centre':centre,
        'points':points,
        'color':colors[i]
    }
    clusters[i]=cluster

# %%
clusters
# Out:
# {0: {'centre': array([-9.43514102,  2.8076574 ]),
#   'points': [],
#   'color': 'red'},
#  1: {'centre': array([ 8.16431103, -6.86634828]),
#   'points': [],
#   'color': 'blue'},
#  2: {'centre': array([-9.02057736, -9.06070578]),
#   'points': [],
#   'color': 'green'},
#  3: {'centre': array([-9.34960625, -3.92691204]),
#   'points': [],
#   'color': 'orange'},
#  4: {'centre': array([-2.94359763, -5.83279304]),
#   'points': [],
#   'color': 'yellow'}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum(((v1-v2)**2)))

# %%
def assignPointToClusters(clusters):  # E-step
    for xi in range(X.shape[0]):
        dist=[]
        currx=X[xi]
    
        for kx in range(k):
            d=distance(currx,clusters[kx]['centre'])
            dist.append(d)
        
        current_cluster=np.argmin(dist)
        clusters[current_cluster]['points'].append(currx)
        
def updateClusters(clusters):       # M-step
    for kx in range(k):
        pts=np.array(clusters[kx]['points'])
        if pts.shape[0]>0:
            new_u=pts.mean(axis=0)
            clusters[kx]['centre']=new_u
            clusters[kx]['points']=[]
            

def plotClusters(clusters):
    for kx in range(k):
        pts=np.array(clusters[kx]['points'])
        print(pts.shape)
        
        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
        except:
            pass
        
        u=clusters[kx]['centre']
        plt.scatter(u[0],u[1],color='black',marker='*')

# %%
plotClusters(clusters)
# Out:
# (300, 2)
# (202, 2)
# (46, 2)
# (286, 2)
# (166, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (450, 2)
# (303, 2)
# (69, 2)
# (429, 2)
# (249, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (66, 2)
# (102, 2)
# (65, 2)
# (144, 2)
# (123, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (95, 2)
# (100, 2)
# (95, 2)
# (109, 2)
# (101, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (98, 2)
# (100, 2)
# (99, 2)
# (103, 2)
# (100, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (98, 2)
# (100, 2)
# (99, 2)
# (103, 2)
# (100, 2)
